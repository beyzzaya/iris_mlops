# %%
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
iris = load_iris(as_frame=True)
iris = iris.frame

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
iris["target"].unique()
# Out:
# array([0, 1, 2])

# %%
iris.isna().sum().sum()
# Out:
# 0

# %%
min_max = []
for i in iris.columns:
    min_max.append(f"{i} min_value = {iris[i].min()}")
    min_max.append(f"{i} max_value = {iris[i].max()}")

# %%
min_max
# Out:
# ['sepal length (cm) min_value = 4.3',
#  'sepal length (cm) max_value = 7.9',
#  'sepal width (cm) min_value = 2.0',
#  'sepal width (cm) max_value = 4.4',
#  'petal length (cm) min_value = 1.0',
#  'petal length (cm) max_value = 6.9',
#  'petal width (cm) min_value = 0.1',
#  'petal width (cm) max_value = 2.5',
#  'target min_value = 0',
#  'target max_value = 2']

# %%
print(iris["'sepal length (cm)"].min())

# %%
iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
iris.hist(figsize=(10,8))
plt.show()

# %%
sns.scatterplot(data=iris, x="petal length (cm)", y="petal width (cm)", hue="target")
plt.show()

# %%
sns.heatmap(iris.corr(), annot=True, cmap="coolwarm")
plt.show()
